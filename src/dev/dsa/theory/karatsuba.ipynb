# %%
def karatsuba(x,y):
	"""Function to multiply 2 numbers in a more efficient manner than the grade school algorithm"""
	if len(str(x)) == 1 or len(str(y)) == 1:
		return x*y
	else:
		n = max(len(str(x)),len(str(y)))
		nby2 = n / 2
		
		a = x / 10**(nby2)
		b = x % 10**(nby2)
		c = y / 10**(nby2)
		d = y % 10**(nby2)
		
		ac = karatsuba(a,c)
		bd = karatsuba(b,d)
		ad_plus_bc = karatsuba(a+b,c+d) - ac - bd
        
        	# this little trick, writing n as 2*nby2 takes care of both even and odd n
		prod = ac * 10**(2*nby2) + (ad_plus_bc * 10**nby2) + bd

		return prod

# %%
print(karatsuba(9987,1234))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 print(karatsuba(9987,1234))
#
# Cell In[109], line 14, in karatsuba(x, y)
#      11 c = y / 10**(nby2)
#      12 d = y % 10**(nby2)
# ---> 14 ac = karatsuba(a,c)
#      15 bd = karatsuba(b,d)
#      16 ad_plus_bc = karatsuba(a+b,c+d) - ac - bd
#
# Cell In[109], line 14, in karatsuba(x, y)
#      11 c = y / 10**(nby2)
#      12 d = y % 10**(nby2)
# ---> 14 ac = karatsuba(a,c)
#      15 bd = karatsuba(b,d)
#      16 ad_plus_bc = karatsuba(a+b,c+d) - ac - bd
#
#     [... skipping similar frames: karatsuba at line 14 (2968 times)]
#
# Cell In[109], line 14, in karatsuba(x, y)
#      11 c = y / 10**(nby2)
#      12 d = y % 10**(nby2)
# ---> 14 ac = karatsuba(a,c)
#      15 bd = karatsuba(b,d)
#      16 ad_plus_bc = karatsuba(a+b,c+d) - ac - bd
#
# Cell In[109], line 3, in karatsuba(x, y)
#       1 def karatsuba(x,y):
#       2 	"""Function to multiply 2 numbers in a more efficient manner than the grade school algorithm"""
# ----> 3 	if len(str(x)) == 1 or len(str(y)) == 1:
#       4 		return x*y
#       5 	else:
#
# RecursionError: maximum recursion depth exceeded while getting the str of an object
